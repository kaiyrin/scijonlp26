# %%
# Now you can plot them together — articles as dots, aims as stars
import matplotlib.pyplot as plt

    plt.figure(figsize=(10, 7))
    plt.scatter(articles_2d[:, 0], articles_2d[:, 1],
                c="steelblue", alpha=0.4, s=20, label="Articles")

    for i, journal_name in enumerate(aim_paths):
        plt.scatter(aims_2d[i, 0], aims_2d[i, 1],
                    marker="*", s=300, label=f"Aim: {journal_name}")

    plt.legend()
    plt.title("Articles vs Journal Aims (UMAP)")
    plt.savefig("data/umap_plot.png", dpi=150)
    plt.show()
